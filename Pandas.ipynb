# %% [markdown]
# <a href="https://colab.research.google.com/github/alishabohara03/Machine-Learning/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas
# Data preprocessing in Machine learning using pandas.
#
# Data preprocessing is required tasks for cleasning the data and making it suitable for a machine learning model which also increases the accuracy and efficiency of a machine learning model.
#
# Pandas is an open source Python package that is most widelyused for data science/data analysis and machine learning tasks. It is built on top of another package named Numpy, which provides support for multi dimensional arrays. Preprocessing is the process of doing a pre-analysis of data, in order to transform them into a standard and normalized format.
#
# Preprocessing involves following aspects:
#
# -missing values
#
# -data standardization
#
# -data normalization
#
# -data minning

# %%
import pandas as pd

# %%
data = {
    "cars": ["bmw", "honda", "suzuki", "BYD" ],
    "models": ["2007", "2009", "2008", "2023"],
    "passengers": ["5", "5", "6", "7"]
}
#print(data)
data
# Out:
# {'cars': ['bmw', 'honda', 'suzuki', 'BYD'],
#  'models': ['2007', '2009', '2008', '2023'],
#  'passengers': ['5', '5', '6', '7']}

# %%
#convert the data into dataframe
df =  pd.DataFrame(data)
df
# Out:
#      cars models passengers
# 0     bmw   2007          5
# 1   honda   2009          5
# 2  suzuki   2008          6
# 3     BYD   2023          7

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# save the file as  CSV file
from google.colab import files
files.download('/content/drive/MyDrive/car_data.csv')

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
#Pandas Series
import pandas as pd
a = [1, 7, 2]
myvar = pd.Series(a)
#myvar
print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
#create labels  in pandas with index
a = [1, 7, 2]
myvar = pd.Series(a, index=["x", "y", "z"])
print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
print(myvar["x"])
# Out:
# 1

# %%
#create a dataframe named df, with data calories and duration.

data = {
    "calories" : [400, 503, 606],
    "duration" :[30, 50, 80]


      }

# %%
#convert the data into dataframe
df =  pd.DataFrame(data)
df
# Out:
#    calories  duration
# 0       400        30
# 1       503        50
# 2       606        80

# %%
print(df.loc[1])
# Out:
# calories    503
# duration     50
# Name: 1, dtype: int64

# %%
print(df.loc[[1, 2]])
# Out:
#    calories  duration
# 1       503        50
# 2       606        80

# %%
import pandas as pd

data = {
    "calories" : [400, 503, 606],
    "duration" :[30, 50, 80]


      }
df = pd.DataFrame(data, index = ["day1", "day2", "day3"])
print(df)
# Out:
#       calories  duration
# day1       400        30
# day2       503        50
# day3       606        80

# %%
import pandas as pd

df.to_csv("")

df
# Out:
#       calories  duration
# day1       400        30
# day2       503        50
# day3       606        80

# %%
import pandas as pd

df=pd.read_csv("/content/drive/MyDrive/pandas_dataset.csv")

df
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01'    110       130     409.1
# 1         60  2020/12/02'    117       145     479.0
# 2         60  2020/12/03'    103       135     340.0
# 3         45  2020/12/04'    109       175     282.4
# 4         45  2020/12/05'    117       148     406.0
# 5         60  2020/12/06'    102       127     300.0
# 6         60  2020/12/07'    110       136     374.0
# 7        450  2020/12/08'    104       134     253.3
# 8         30  2020/12/09'    109       133     195.1
# 9         60  2020/12/10'     98       124     269.0
# 10        60  2020/12/11'    103       147     329.3
# 11        60  2020/12/12'    100       120     250.7
# 12        60  2020/12/12'    100       120     250.7
# 13        60  2020/12/13'    106       128     345.3
# 14        60  2020/12/14'    104       132     379.3
# 15        60  2020/12/15'     98       123     275.0
# 16        60  2020/12/16'     98       120     215.2
# ...

# %%
df.head()
# Out:
#    Duration         Date  Pulse  Maxpulse  Calories
# 0        60  2020/12/01'    110       130     409.1
# 1        60  2020/12/02'    117       145     479.0
# 2        60  2020/12/03'    103       135     340.0
# 3        45  2020/12/04'    109       175     282.4
# 4        45  2020/12/05'    117       148     406.0

# %%
df.tail()
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 27        60  2020/12/27'     92       118     241.0
# 28        60  2020/12/28'    103       132       NaN
# 29        60  2020/12/29'    100       132     280.0
# 30        60  2020/12/30'    102       129     380.3
# 31        60  2020/12/31'     92       115     243.0

# %%
df.shape
# Out:
# (32, 5)

# %%
data_types=df.dtypes
data_types
# Out:
# Duration      int64
# Date         object
# Pulse         int64
# Maxpulse      int64
# Calories    float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
isnull= df.isnull()
isnull_count = isnull.sum()
print("Total number of null values:", isnull_count)
# Out:
# Total number of null values: Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
#total nulls in dataset
total_isnull_count = isnull.sum().sum()
print("Total nulls:", total_isnull_count)
# Out:
# Total nulls: 3

# %%
df
# Out:
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01'    110       130     409.1
# 1         60  2020/12/02'    117       145     479.0
# 2         60  2020/12/03'    103       135     340.0
# 3         45  2020/12/04'    109       175     282.4
# 4         45  2020/12/05'    117       148     406.0
# 5         60  2020/12/06'    102       127     300.0
# 6         60  2020/12/07'    110       136     374.0
# 7        450  2020/12/08'    104       134     253.3
# 8         30  2020/12/09'    109       133     195.1
# 9         60  2020/12/10'     98       124     269.0
# 10        60  2020/12/11'    103       147     329.3
# 11        60  2020/12/12'    100       120     250.7
# 12        60  2020/12/12'    100       120     250.7
# 13        60  2020/12/13'    106       128     345.3
# 14        60  2020/12/14'    104       132     379.3
# 15        60  2020/12/15'     98       123     275.0
# 16        60  2020/12/16'     98       120     215.2
# ...

# %%
#replace single quote with blank and make the date formmated
df["Date"] =df["Date"].replace("'", "", regex= True)
df
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
# handle null values, retuurn dataframe with no empty cells
#we can use df.dropna() , it removes empty cells but will not change the dataframe
#if we want data frame to be changed , simply use inplace=True
new_df= df.dropna()
new_df
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
isnull_count_newdf = new_df.isnull().sum()
print(isnull_count_newdf)
# Out:
# Duration    0
# Date        0
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %%
#another way of handling the null values is by replacing the null values
df.fillna(130, inplace=True)
df
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
df=pd.read_csv("/content/drive/MyDrive/pandas_dataset.csv")
df["Calories"].fillna(130, inplace=True)
df
# Out:
# <ipython-input-22-4f5a5c1ca5e7>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Calories"].fillna(130, inplace=True)
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01'    110       130     409.1
# 1         60  2020/12/02'    117       145     479.0
# 2         60  2020/12/03'    103       135     340.0
# 3         45  2020/12/04'    109       175     282.4
# 4         45  2020/12/05'    117       148     406.0
# 5         60  2020/12/06'    102       127     300.0
# ...

# %%
#fill specific with mean median and mode
df=pd.read_csv("/content/drive/MyDrive/pandas_dataset.csv")
x = df["Calories"].mean()
df["Calories"].fillna(x, inplace = True)
df
# Out:
# <ipython-input-23-c9f8bc44859d>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Calories"].fillna(x, inplace = True)
#     Duration         Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01'    110       130    409.10
# 1         60  2020/12/02'    117       145    479.00
# 2         60  2020/12/03'    103       135    340.00
# 3         45  2020/12/04'    109       175    282.40
# 4         45  2020/12/05'    117       148    406.00
# 5         60  2020/12/06'    102       127    300.00
# ...

# %%
df=pd.read_csv("/content/drive/MyDrive/Video_Games_Sales_as_at_22_Dec_2016.csv")
df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
df.shape
# Out:
# (16719, 16)

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %%
df.tail()
# Out:
#                                 Name Platform  Year_of_Release       Genre  \
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0      Action
# 16715               LMA Manager 2007     X360           2006.0      Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0   Adventure
# 16717               Spirits & Spells      GBA           2003.0    Platform
# 16718            Winning Post 8 2016      PSV           2016.0  Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 16714    Tecmo Koei      0.00      0.00      0.01          0.0          0.01
# 16715   Codemasters      0.00      0.01      0.00          0.0          0.01
# 16716  Idea Factory      0.00      0.00      0.01          0.0          0.01
# 16717       Wanadoo      0.01      0.00      0.00          0.0          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01          0.0          0.01
#
# ...

# %%
df.isnull().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         9129
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
df.dtypes
# Out:
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score         float64
# User_Count         float64
# Developer           object
# Rating              object
# dtype: object

# %%
df.isnull().sum().sum()
# Out:
# 49141

# %%
df.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %%
df= df[['Name','Year_of_Release', 'Genre', 'Publisher','Critic_Score',
       'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating']].fillna("unknown")

# %%
df[['Name','Year_of_Release', 'Genre', 'Publisher','Critic_Score',
       'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating']].isnull().sum()
# Out:
# Name               0
# Year_of_Release    0
# Genre              0
# Publisher          0
# Critic_Score       0
# Critic_Count       0
# User_Score         0
# User_Count         0
# Developer          0
# Rating             0
# dtype: int64

# %% [markdown]
# ###Reading files

# %% [markdown]
# indexing

# %%
import pandas as pd


wfx=pd.read_csv("/content/drive/MyDrive/Flavors.csv")
sxf=pd.read_csv("/content/drive/MyDrive/Ice Cream Ratings.csv")
rxf=pd.read_csv("/content/drive/MyDrive/LOTR.csv")
tfx=pd.read_csv("/content/drive/MyDrive/dataset(1).csv")
fdx=pd.read_csv("/content/drive/MyDrive/world_population.csv")

# %%
import pandas as pd
ccl= pd.read_excel("/content/drive/MyDrive/Customer Call List.xlsx")

# %%
#read world_population.csv

import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/world_population.csv")
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#      index  Rank CCA3            Country           Capital Continent  \
# 0        0    36  AFG        Afghanistan             Kabul      Asia
# 1        1   138  ALB            Albania            Tirana    Europe
# 2        2    34  DZA            Algeria           Algiers    Africa
# 3        3   213  ASM     American Samoa         Pago Pago   Oceania
# 4        4   203  AND            Andorra  Andorra la Vella    Europe
# ..     ...   ...  ...                ...               ...       ...
# 229    229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230    230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    231    46  YEM              Yemen             Sanaa      Asia
# 232    232    63  ZMB             Zambia            Lusaka    Africa
# 233    233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# ...

# %%
df.set_index('Country', inplace= True)
df
# Out:
#                    index  Rank CCA3           Capital Continent  \
# Country
# Afghanistan            0    36  AFG             Kabul      Asia
# Albania                1   138  ALB            Tirana    Europe
# Algeria                2    34  DZA           Algiers    Africa
# American Samoa         3   213  ASM         Pago Pago   Oceania
# Andorra                4   203  AND  Andorra la Vella    Europe
# ...                  ...   ...  ...               ...       ...
# Wallis and Futuna    229   226  WLF          Mata-Utu   Oceania
# Western Sahara       230   172  ESH          El Aaiún    Africa
# Yemen                231    46  YEM             Sanaa      Asia
# Zambia               232    63  ZMB            Lusaka    Africa
# Zimbabwe             233    74  ZWE            Harare    Africa
#
#                    2022 Population  2020 Population  2015 Population  \
# Country
# Afghanistan             41128771.0       38972230.0       33753499.0
# ...

# %%
df.loc['Albania']
df
# Out:
#                    index  Rank CCA3           Capital Continent  \
# Country
# Afghanistan            0    36  AFG             Kabul      Asia
# Albania                1   138  ALB            Tirana    Europe
# Algeria                2    34  DZA           Algiers    Africa
# American Samoa         3   213  ASM         Pago Pago   Oceania
# Andorra                4   203  AND  Andorra la Vella    Europe
# ...                  ...   ...  ...               ...       ...
# Wallis and Futuna    229   226  WLF          Mata-Utu   Oceania
# Western Sahara       230   172  ESH          El Aaiún    Africa
# Yemen                231    46  YEM             Sanaa      Asia
# Zambia               232    63  ZMB            Lusaka    Africa
# Zimbabwe             233    74  ZWE            Harare    Africa
#
#                    2022 Population  2020 Population  2015 Population  \
# Country
# Afghanistan             41128771.0       38972230.0       33753499.0
# ...

# %%
df.iloc[1]
df
# Out:
#                    index  Rank CCA3           Capital Continent  \
# Country
# Afghanistan            0    36  AFG             Kabul      Asia
# Albania                1   138  ALB            Tirana    Europe
# Algeria                2    34  DZA           Algiers    Africa
# American Samoa         3   213  ASM         Pago Pago   Oceania
# Andorra                4   203  AND  Andorra la Vella    Europe
# ...                  ...   ...  ...               ...       ...
# Wallis and Futuna    229   226  WLF          Mata-Utu   Oceania
# Western Sahara       230   172  ESH          El Aaiún    Africa
# Yemen                231    46  YEM             Sanaa      Asia
# Zambia               232    63  ZMB            Lusaka    Africa
# Zimbabwe             233    74  ZWE            Harare    Africa
#
#                    2022 Population  2020 Population  2015 Population  \
# Country
# Afghanistan             41128771.0       38972230.0       33753499.0
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#     Continent            Country  Rank CCA3           Capital  \
# 0        Asia        Afghanistan    36  AFG             Kabul
# 1      Europe            Albania   138  ALB            Tirana
# 2      Africa            Algeria    34  DZA           Algiers
# 3     Oceania     American Samoa   213  ASM         Pago Pago
# 4      Europe            Andorra   203  AND  Andorra la Vella
# ..        ...                ...   ...  ...               ...
# 229   Oceania  Wallis and Futuna   226  WLF          Mata-Utu
# 230    Africa     Western Sahara   172  ESH          El Aaiún
# 231      Asia              Yemen    46  YEM             Sanaa
# 232    Africa             Zambia    63  ZMB            Lusaka
# 233    Africa           Zimbabwe    74  ZWE            Harare
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
df.drop(columns=['index'], inplace=True)
df
# Out:
#                              Rank CCA3           Capital  2022 Population  \
# Continent Country
# Asia      Afghanistan          36  AFG             Kabul       41128771.0
# Europe    Albania             138  ALB            Tirana        2842321.0
# Africa    Algeria              34  DZA           Algiers       44903225.0
# Oceania   American Samoa      213  ASM         Pago Pago          44273.0
# Europe    Andorra             203  AND  Andorra la Vella          79824.0
# ...                           ...  ...               ...              ...
# Oceania   Wallis and Futuna   226  WLF          Mata-Utu          11572.0
# Africa    Western Sahara      172  ESH          El Aaiún         575986.0
# Asia      Yemen                46  YEM             Sanaa       33696614.0
# Africa    Zambia               63  ZMB            Lusaka       20017675.0
#           Zimbabwe             74  ZWE            Harare       16320537.0
#
# ...

# %%
df.set_index(['Continent', 'Country'], inplace=True)
df
# Out:
#                              Rank CCA3           Capital  2022 Population  \
# Continent Country
# Asia      Afghanistan          36  AFG             Kabul       41128771.0
# Europe    Albania             138  ALB            Tirana        2842321.0
# Africa    Algeria              34  DZA           Algiers       44903225.0
# Oceania   American Samoa      213  ASM         Pago Pago          44273.0
# Europe    Andorra             203  AND  Andorra la Vella          79824.0
# ...                           ...  ...               ...              ...
# Oceania   Wallis and Futuna   226  WLF          Mata-Utu          11572.0
# Africa    Western Sahara      172  ESH          El Aaiún         575986.0
# Asia      Yemen                46  YEM             Sanaa       33696614.0
# Africa    Zambia               63  ZMB            Lusaka       20017675.0
#           Zimbabwe             74  ZWE            Harare       16320537.0
#
# ...

# %%
df.sort_index()
# Out:
#                             Rank CCA3      Capital  2022 Population  \
# Continent     Country
# Africa        Algeria         34  DZA      Algiers       44903225.0
#               Angola          42  AGO       Luanda       35588987.0
#               Benin           77  BEN   Porto-Novo       13352864.0
#               Botswana       144  BWA     Gaborone        2630296.0
#               Burkina Faso    58  BFA  Ouagadougou       22673762.0
# ...                          ...  ...          ...              ...
# South America Paraguay       109  PRY     Asunción        6780744.0
#               Peru            44  PER         Lima       34049588.0
#               Suriname       170  SUR   Paramaribo         618040.0
#               Uruguay        133  URY   Montevideo        3422794.0
#               Venezuela       51  VEN      Caracas       28301696.0
#
#                             2020 Population  2015 Population  2010 Population  \
# Continent     Country
# ...

# %%
df.loc['Africa', 'Angola']
# Out:
# Rank                                   42
# CCA3                                  AGO
# Capital                            Luanda
# 2022 Population                35588987.0
# 2020 Population                33428485.0
# 2015 Population                28127721.0
# 2010 Population                23364185.0
# 2000 Population                16394062.0
# 1990 Population                11828638.0
# 1980 Population                 8330047.0
# 1970 Population                 6029700.0
# Area (km²)                      1246700.0
# Density (per km²)                 28.5466
# Growth Rate                        1.0315
# World Population Percentage          0.45
# Name: (Africa, Angola), dtype: object

# %% [markdown]
# Group by and Aggregating

# %%
import pandas as pd
df= pd.read_csv("/content/drive/MyDrive/Flavors.csv")
df
# Out:
#                    Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    Total Rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %%
group_by_frame =df.groupby('Base Flavor')

# %%
type(group_by_frame)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
group_by_frame.mean(numeric_only=True)
# Out:
#              Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate              8.4        7.233333         15.70
# Vanilla                5.7        5.650000         11.35

# %%
group_by_frame.count()
# Out:
#              Flavor  Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate         3      3              3               3             3
# Vanilla           6      6              6               6             6

# %%
group_by_frame.sum()
# Out:
#                                                         Flavor  \
# Base Flavor
# Chocolate            ChocolateRocky RoadChocolte Fudge Brownie
# Vanilla      Mint Chocolate ChipVanillaCookie DoughPistachi...
#
#                        Liked  Flavor Rating  Texture Rating  Total Rating
# Base Flavor
# Chocolate          YesYesYes           25.2            21.7          47.1
# Vanilla      YesNoYesNoYesNo           34.2            33.9          68.1

# %%
df.groupby(['Base Flavor', 'Liked']).agg({'Flavor Rating':['mean', 'max', 'count', 'sum']})
# Out:
#                   Flavor Rating
#                            mean   max count   sum
# Base Flavor Liked
# Chocolate   Yes             8.4   8.8     3  25.2
# Vanilla     No              3.6   4.7     3  10.8
#             Yes             7.8  10.0     3  23.4

# %%
group_by_frame.describe()
# Out:
#             Flavor Rating                                             \
#                     count mean       std  min    25%  50%  75%   max
# Base Flavor
# Chocolate             3.0  8.4  0.346410  8.2  8.200  8.2  8.5   8.8
# Vanilla               6.0  5.7  2.710719  2.3  4.025  5.6  6.8  10.0
#
#             Texture Rating            ...             Total Rating         \
#                      count      mean  ...    75%  max        count   mean
# Base Flavor                           ...
# Chocolate              3.0  7.233333  ...  7.350  7.6          3.0  15.70
# Vanilla                6.0  5.650000  ...  6.375  8.0          6.0  11.35
#
#
#                   std   min     25%   50%     75%   max
# Base Flavor
# Chocolate    0.781025  15.2  15.250  15.3  15.950  16.6
# Vanilla      4.263684   5.7   9.025  11.1  13.175  18.0
#
# [2 rows x 24 columns]

# %% [markdown]
# ### Data merge, Concatinate and join

# %%
import pandas as pd

df1=pd.read_csv("/content/drive/MyDrive/LOTR.csv")
df1
# Out:
#    FellowshipID FirstName     Skills
# 0          1001     Frodo     Hiding
# 1          1002   Samwise  Gardening
# 2          1003   Gandalf     Spells
# 3          1004    Pippin  Fireworks

# %%
df2= pd.read_csv("/content/drive/MyDrive/LOTR 2.csv")
df2
# Out:
#    FellowshipID FirstName   Age
# 0          1001     Frodo    50
# 1          1002   Samwise    39
# 2          1006   Legolas  2931
# 3          1007    Elrond  6520
# 4          1008  Barromir    51

# %%
df1.merge(df2, how='inner', on=['FellowshipID', 'FirstName'])
# Out:
#    FellowshipID FirstName     Skills  Age
# 0          1001     Frodo     Hiding   50
# 1          1002   Samwise  Gardening   39

# %%
df1.merge(df2, how='outer',)
# Out:
#    FellowshipID FirstName     Skills     Age
# 0          1001     Frodo     Hiding    50.0
# 1          1002   Samwise  Gardening    39.0
# 2          1003   Gandalf     Spells     NaN
# 3          1004    Pippin  Fireworks     NaN
# 4          1006   Legolas        NaN  2931.0
# 5          1007    Elrond        NaN  6520.0
# 6          1008  Barromir        NaN    51.0

# %%
df1.merge(df2, how='left', on=['FellowshipID', 'FirstName'])
# Out:
#    FellowshipID FirstName     Skills   Age
# 0          1001     Frodo     Hiding  50.0
# 1          1002   Samwise  Gardening  39.0
# 2          1003   Gandalf     Spells   NaN
# 3          1004    Pippin  Fireworks   NaN

# %%
df1.merge(df2, how='right', on=['FellowshipID', 'FirstName'])
# Out:
#    FellowshipID FirstName     Skills   Age
# 0          1001     Frodo     Hiding    50
# 1          1002   Samwise  Gardening    39
# 2          1006   Legolas        NaN  2931
# 3          1007    Elrond        NaN  6520
# 4          1008  Barromir        NaN    51

# %% [markdown]
# #concatenate df1 and df2

# %%
result= pd.concat([df1, df2])
result
# Out:
#    FellowshipID FirstName     Skills     Age
# 0          1001     Frodo     Hiding     NaN
# 1          1002   Samwise  Gardening     NaN
# 2          1003   Gandalf     Spells     NaN
# 3          1004    Pippin  Fireworks     NaN
# 0          1001     Frodo        NaN    50.0
# 1          1002   Samwise        NaN    39.0
# 2          1006   Legolas        NaN  2931.0
# 3          1007    Elrond        NaN  6520.0
# 4          1008  Barromir        NaN    51.0
